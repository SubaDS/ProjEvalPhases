# %% [markdown]
# # Avocado Project

# %% [markdown]
# # Project Description
#
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g.greenskins) are not included in this table.
# Some relevant columns in the dataset:
# •	Date - The date of the observation
# •	AveragePrice - the average price of a single avocado
# •	type - conventional or organic
# •	year - the year
# •	Region - the city or region of the observation
# •	Total Volume - Total number of avocados sold
# •	4046 - Total number of avocados with PLU 4046 sold
# •	4225 - Total number of avocados with PLU 4225 sold
# •	4770 - Total number of avocados with PLU 4770 sold

# %%
from IPython.display import Image
Image(url="https://cdn.pixabay.com/photo/2020/09/02/10/20/hass-avocados-5537945_1280.jpg")
# Out:
# <img src="https://cdn.pixabay.com/photo/2020/09/02/10/20/hass-avocados-5537945_1280.jpg"/>

# %%
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
(r"C:\Users\Premium\Downloads\avocado.csv\avocado.csv")
df_ava.head(20)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76   842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86   75595.85
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_ava.shape
# Out:
# (18249, 14)

# %% [markdown]
# The dataset comprises of 18249 observations of 14 columns

# %%
df_ava.columns  # This will print the names of all columns.
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df_ava.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# The variable "Unnamed:0" is just representation of indicies so we are dropping out.

# %%
df_ava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df_ava.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
#  From info we have seen that Date is Object type not the date type. We have to change its type to date type since we will be using this for our machine learning models.

# %%
df_ava['Date']=pd.to_datetime(df_ava['Date'])
df_ava['Month']=df_ava['Date'].apply(lambda x:x.month)
df_ava['Day']=df_ava['Date'].apply(lambda x:x.day)
df_ava.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# ...

# %%
df_ava.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %%
df_ava.AveragePrice.value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
df_ava.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %% [markdown]
# we can see that the AveragePrice column is our dependent variable and is continous in nature,thus it is a linear regression problem.

# %% [markdown]
# #  Checking for Missing Values

# %%
df_ava.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df_ava.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Thus we can see clearly that there are no NULL values in our Dataset

# %% [markdown]
# # Statistical summary

# %%
df_ava.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# # Analysis of Average Prices

# %%
import matplotlib.pyplot as plt

byDate=df_ava.groupby('Date').mean()
plt.figure(figsize=(17,8),dpi=100)
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %%
byMonth = df_ava.groupby("Month").mean()
plt.figure(figsize=(17,8),dpi=100)
plt.plot(["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"],byMonth['AveragePrice'])
plt.title('Average Price Per Month')
# Out:
# Text(0.5, 1.0, 'Average Price Per Month')

# %% [markdown]
# we can observe that the price rises for a while in February to March then it falls in April and then the month of May witnesses a rise in the average price. This rise reaches its highness in the month of October and henceforth it starts to fall.

# %% [markdown]
# # Average price Distribution

# %%
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a=df_ava.AveragePrice, kde=False, fit=norm)
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %% [markdown]
# Average Price distribution shows that for most cases price of avocado is between 1.1, 1.4.
# Let's look at average price of conventional vs. organic.

# %% [markdown]
# # Average Price distribution over months for convetional and organic types

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df_ava)
plt.show()

# %% [markdown]
# There was a hike between months 8 – 10 for both Conventional and Organic type of Avocados prices

# %% [markdown]
# # Average price distribution based on region.

# %%
region_list=list(df_ava.region.unique())
average_price=[]

for i in region_list:
    x=df_ava[df_ava.region==i]
    region_average=sum(x.AveragePrice)/len(x)
    average_price.append(region_average)

df1=pd.DataFrame({'region_list':region_list,'average_price':average_price})
new_index=df1.average_price.sort_values(ascending=False).index.values
sorted_data=df1.reindex(new_index)

plt.figure(figsize=(24,10))
ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %% [markdown]
# Looks like these region are where price is very high
#
# HartfordSpringfield
#
# SanFrancisco
#
# NewYork
#
# Philadelphia
#
# Sacramento

# %% [markdown]
# # Regions where Average consumption is very high.

# %%
filter1=df_ava.region!='TotalUS'
df1=df_ava[filter1]

region_list=list(df1.region.unique())
average_total_volume=[]

for i in region_list:
    x=df1[df1.region==i]
    average_total_volume.append(sum(x['Total Volume'])/len(x))
df3=pd.DataFrame({'region_list':region_list,'average_total_volume':average_total_volume})

new_index=df3.average_total_volume.sort_values(ascending=False).index.values
sorted_data1=df3.reindex(new_index)

plt.figure(figsize=(22,10))
ax=sns.barplot(x=sorted_data1.region_list,y=sorted_data1.average_total_volume)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average of Total Volume')
plt.title('Average of Total Volume According to Region')
# Out:
# Text(0.5, 1.0, 'Average of Total Volume According to Region')

# %% [markdown]
# these are regions where Consumption is very high
#
# West
#
# California
#
# SouthCentral
#
# Northeast
#
# Southeast

# %% [markdown]
# # Analysis for the year and Region was the Average Price High:

# %%
sns.factorplot('AveragePrice','region',data=df_ava,
                   hue='year',
                   size=18,
                   aspect=0.7,
                   palette='Blues',
                   join=False,
              )

# %% [markdown]
# A factor plot is simply the same plot generated for different response and factor variables and arranged on a single page. The underlying plot generated can be any univariate or bivariate plot. The scatter plot is the most common application. The above plot is a factor plot of average avocado price for different regions classified by year.
#
# There was a huge increase in Avocado prices as the demand was little high in Year 2017 in SanFranciso region.

# %% [markdown]
# # price distributed over the date column

# %%
byDate=df_ava.groupby('Date').mean()
plt.figure(figsize=(12,8))
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# This also shows there was a huge hike in prices after July 2017 and before Jan 2018. This was also confirmed in earlier graph too.

# %% [markdown]
# # Data Correlation

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_ava.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can from the heatmap above, all the Features are not correlated with the Average Price column, instead most of them are correlated with each other.

# %% [markdown]
# # Checking for the outliers

# %%
plt.figure(figsize=(15,7),dpi=100)
sns.boxplot(data = df_ava[[
 'AveragePrice',
 'Total Volume',
 '4046',
 '4225',
 '4770',
 'Total Bags',
 'Small Bags',
 'Large Bags',
 'XLarge Bags']])
# Out:
# <AxesSubplot:>

# %%
df_ava.drop(columns=["Date"],inplace=True)
df_ava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  Month         18249 non-null  int64
#  13  Day           18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# we have removed the "Date" variable from our dataset as it is useless now

# %%
import numpy as np
from numpy import percentile

columns = df_ava.columns
for j in columns:
    if isinstance(df_ava[j][0], str) :
        continue
    else:
        #defining quartiles
        quartiles = percentile(df_ava[j], [25,75])
        # calculate min/max
        lower_fence = quartiles[0] - (1.5*(quartiles[1]-quartiles[0]))
        upper_fence = quartiles[1] + (1.5*(quartiles[1]-quartiles[0]))
        df_ava[j] = df_ava[j].apply(lambda x: upper_fence if x > upper_fence else (lower_fence if x < lower_fence else x))

# %% [markdown]
# In the above code we have we replaced the outliers higer than the upper whisker by the value of the upper whisker and the outliers lower than the lower whisker by the value of the lower whisker.

# %%
df_ava.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
plt.figure(figsize=(15,7),dpi=100)
sns.boxplot(data = df_ava[[
 'AveragePrice',
 'Total Volume',
 '4046',
 '4225',
 '4770',
 'Total Bags',
 'Small Bags',
 'Large Bags',
 'XLarge Bags']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Clearly our data is free from outliers. Now we can fit our data to appropriate models

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Since our data contains categorical variables like "type" and "region" we must apply label encoder techniques and convert them to integer format.

# %%
df_ava['region'].nunique()
# Out:
# 54

# %%
df_ava['type'].nunique()
# Out:
# 2

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df_ava['type']=le.fit_transform(df_ava['type'])

# %%
df_ava['region']=le.fit_transform(df_ava['region'])

# %%
df_ava['type']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18244    1
# 18245    1
# 18246    1
# 18247    1
# 18248    1
# Name: type, Length: 18249, dtype: int32

# %%
df_ava['region']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 18249, dtype: int32

# %%
df_ava.sample(5)
# Out:
#        AveragePrice  Total Volume        4046       4225      4770  \
# 2737           0.94   1066147.855  276269.395  371003.98  15608.55
# 9085           0.98    853642.900  276269.395   79267.58   1096.90
# 13935          1.19      9200.040     343.510    4176.52    391.47
# 11041          1.32     30280.670   17519.030   12225.23     35.68
# 9784           1.03    139212.260   88780.660   36428.10    143.56
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  \
# 2737   269325.465  204070.045    54881.92       242.69     0  2015      52
# 9085   208593.230   91618.580    54881.92       170.00     0  2018      50
# 13935    4288.540    1732.800     2555.74         0.00     1  2016      38
# 11041     500.730       0.000      500.73         0.00     1  2015      36
# 9784    13859.940    2957.810    10902.13         0.00     1  2015      12
#
#        Month  Day
# 2737       5   10
# 9085       2    4
# 13935      6   26
# 11041      3    1
# ...

# %% [markdown]
# Now we can see all the variables are converted into integer type.so we can proceed with our machine learning algorithms and predictions.

# %% [markdown]
# # Separating independent variable and target variable.

# %%
x1=df_ava.drop('AveragePrice',axis=1)
y1=df_ava['AveragePrice']

# %%
x1.skew()
# Out:
# Total Volume    1.206542
# 4046            1.251184
# 4225            1.219271
# 4770            1.212184
# Total Bags      1.158550
# Small Bags      1.186103
# Large Bags      1.215301
# XLarge Bags     1.175351
# type            0.000329
# year            0.215339
# Month           0.106617
# Day             0.014310
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x1)
df_new=pd.DataFrame(df_new,columns=x1.columns)

# %%
df_new.skew()
# Out:
# Total Volume   -0.084632
# 4046           -0.122462
# 4225           -0.135710
# 4770           -0.045993
# Total Bags     -0.130493
# Small Bags     -0.165210
# Large Bags     -0.213020
# XLarge Bags     0.742922
# type            0.000329
# year            0.213156
# Month          -0.146584
# Day            -0.208462
# dtype: float64

# %%
df_new.head()
# Out:
#    Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0     -0.146630 -0.737354  0.347372 -0.286648   -0.637273   -0.439968
# 1     -0.222763 -0.854694  0.252614 -0.238316   -0.597400   -0.400911
# 2      0.159021 -0.810504  0.700997 -0.031424   -0.666267   -0.469014
# 3     -0.044956 -0.712712  0.485012 -0.182731   -0.810639   -0.613085
# 4     -0.257435 -0.764111  0.244122 -0.171705   -0.784680   -0.591781
#
#    Large Bags  XLarge Bags      type      year     Month       Day
# 0   -0.865408    -0.707352 -0.999836 -1.221895  1.494347  1.229285
# 1   -0.855736    -0.707352 -0.999836 -1.221895  1.494347  0.541005
# 2   -0.843393    -0.707352 -0.999836 -1.221895  1.494347 -0.215570
# 3   -0.785138    -0.707352 -0.999836 -1.221895  1.494347 -1.091311
# 4   -0.693490    -0.707352 -0.999836 -1.221895  1.278438  1.416727

# %% [markdown]
# # Creating train test split

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x=df_new
x.shape
# Out:
# (18249, 12)

# %%
y=y1
y.shape
# Out:
# (18249,)

# %%
y.shape
# Out:
# (18249,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=52)

# %%
x_train.shape
# Out:
# (12774, 12)

# %%
x_test.shape
# Out:
# (5475, 12)

# %%
y_train.shape
# Out:
# (12774,)

# %%
y_test.shape
# Out:
# (5475,)

# %% [markdown]
# # Finding Best Algorithm using multiple models

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
lm=LinearRegression()
dtr=DecisionTreeRegressor()
svr=SVR()
knr=KNeighborsRegressor()
ls=Lasso(alpha=0.0001)
rd=Ridge(alpha=0.0001)

# %%
model=[lm,dtr,svr,knr,ls,rd]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('error:',m)
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error: LinearRegression()
# Mean absolute error: 0.20370358617348566
# Mean squared error: 0.06571684018308224
# Root Mean squared error: 0.25635296016056114
# error: DecisionTreeRegressor()
# Mean absolute error: 0.1412590954555338
# Mean squared error: 0.04407854474419905
# Root Mean squared error: 0.20994890984284498
# error: SVR()
# Mean absolute error: 0.1431631394391781
# Mean squared error: 0.03532959389000193
# Root Mean squared error: 0.18796168197268806
# error: KNeighborsRegressor()
# Mean absolute error: 0.13703269406392693
# Mean squared error: 0.03378540347031963
# Root Mean squared error: 0.18380806149437415
# error: Lasso(alpha=0.0001)
# Mean absolute error: 0.2036831043078391
# Mean squared error: 0.06571102590407565
# Root Mean squared error: 0.2563416195315846
# error: Ridge(alpha=0.0001)
# Mean absolute error: 0.2037035855066796
# Mean squared error: 0.06571683989269438
# Root Mean squared error: 0.25635295959417825

# %% [markdown]
# From the above results we can see that the KNeighborsRegressor has minimum error.

# %% [markdown]
# # Let's check the r2_score for all the models

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('score:',m)
    print(r2_score(y_test,pred))
# Out:
# score: LinearRegression()
# 0.5737782611150302
# score: DecisionTreeRegressor()
# 0.7154834459949513
# score: SVR()
# 0.770861762374069
# score: KNeighborsRegressor()
# 0.7808769658441825
# score: Lasso(alpha=0.0001)
# 0.5738159709638548
# score: Ridge(alpha=0.0001)
# 0.5737782629984076

# %% [markdown]
# From the above results we can see that the KNeighborsRegressor has maximum r2_score.

# %%
sns.distplot((y_test-pred),bins=50)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# Notice here that our residuals looked to be normally distributed and that's really a good sign which means that our model was a correct choice for the data.

# %% [markdown]
#  #  Actual Vs Predicted sample.

# %%
data = pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#        Y Test      Pred
# 1930     1.00  1.323505
# 7535     1.25  1.346752
# 9948     1.60  1.502681
# 8134     1.12  1.348036
# 15630    1.93  1.635526

# %% [markdown]
# #### we declare  KNeighborsRegressor model as the best suited model for our purpose of predicting average avocado prices.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('score:',m)
    print(score)
    print(score.mean())
# Out:
# score: LinearRegression()
# [-0.17937618  0.25184216  0.4962751   0.26252047  0.29721162]
# 0.2256946343160871
# score: DecisionTreeRegressor()
# [-0.8503778   0.11020485  0.34971726 -0.24834186 -0.46037664]
# -0.2198348385629852
# score: SVR()
# [-0.34993388  0.55039659  0.47778548  0.28567677 -0.02199212]
# 0.1883865676423349
# score: KNeighborsRegressor()
# [-0.32027984  0.36998121  0.56377736  0.03334147 -0.11646465]
# 0.10607111028592717
# score: Lasso(alpha=0.0001)
# [-0.1806168   0.25277458  0.49653155  0.26253135  0.29620112]
# 0.2254843598886203
# score: Ridge(alpha=0.0001)
# [-0.17937623  0.25184217  0.49627511  0.26252048  0.29721161]
# 0.22569462880715604

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
dtr=DecisionTreeRegressor()
grid_param={'criterion':['mse','mae','friedman_mse','poisson']}
gd_sr=GridSearchCV(estimator=dtr,
                   scoring='accuracy',
                   param_grid=grid_param,
                   cv=5)
gd_sr.fit(x_train,y_train)
best_parameters=gd_sr.best_params_
print(best_parameters)
# Out:
# {'criterion': 'mse'}

# %%
dtr=DecisionTreeRegressor(criterion='mse')
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 0.9956570927504782

# %%
param={'n_neighbors':np.arange(1,12,2),
      'weights':['uniform','distance']}
knr=KNeighborsRegressor()
gscv=GridSearchCV(knr,param,cv=5)
gscv.fit(x_train,y_train)

best_parameters=gscv.best_params_
print(best_parameters)
# Out:
# {'n_neighbors': 5, 'weights': 'distance'}

# %%
knr=KNeighborsRegressor(weights='distance')
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 0.9956079896497406

# %% [markdown]
# # Saving our Model

# %%
import joblib
joblib.dump(ls, 'lsfile.obj')
ls_from_joblib=joblib.load('lsfile.obj')
